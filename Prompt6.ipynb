# %% [markdown]
# # Prompt-6

# %% [markdown]
# #import numpy into the notebook

# %%
import numpy as np
import sys

# %% [markdown]
# #define functions that return x, sin(x), and cos(x)

# %%
x = np.linspace(0,2*np.pi,num=1000)
sinx = np.sin(x)
cosx = np.cos(x)
def f(x):
    return(x, np.sin(x), np.cos(x))

# %% [markdown]
# #tabulate results that used previous functions using print commands

# %%
    print(f"    x    |    sin(x)    |    cos(x)")
    print("------------------------------------")
# Out:
#     x    |    sin(x)    |    cos(x)
# ------------------------------------

# %% [markdown]
# #use a for loop to print the first 10 variables of x, sin(x), and cos(x)

# %%
    print(f"    x    |    sin(x)    |    cos(x)")
    print("------------------------------------")
for i in range(1000):
        print(f"{x[i]:.10f} | {sinx[i]:.10f} | {cosx[i]:.10f}")
# Out:
#     x    |    sin(x)    |    cos(x)
# ------------------------------------
# 0.0000000000 | 0.0000000000 | 1.0000000000
# 0.0062894748 | 0.0062894333 | 0.9999802213
# 0.0125789496 | 0.0125786178 | 0.9999208861
# 0.0188684243 | 0.0188673048 | 0.9998219966
# 0.0251578991 | 0.0251552454 | 0.9996835567
# 0.0314473739 | 0.0314421909 | 0.9995055721
# 0.0377368487 | 0.0377278927 | 0.9992880496
# 0.0440263235 | 0.0440121020 | 0.9990309980
# 0.0503157983 | 0.0502945704 | 0.9987344273
# 0.0566052730 | 0.0565750492 | 0.9983983493
# 0.0628947478 | 0.0628532900 | 0.9980227773
# 0.0691842226 | 0.0691290446 | 0.9976077261
# 0.0754736974 | 0.0754020646 | 0.9971532122
# 0.0817631722 | 0.0816721019 | 0.9966592536
# 0.0880526469 | 0.0879389084 | 0.9961258698
# 0.0943421217 | 0.0942022363 | 0.9955530818
# 0.1006315965 | 0.1004618379 | 0.9949409124
# 0.1069210713 | 0.1067174654 | 0.9942893857
# 0.1132105461 | 0.1129688714 | 0.9935985276
# 0.1195000209 | 0.1192158087 | 0.9928683654
# ...
