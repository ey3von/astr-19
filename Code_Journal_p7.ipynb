# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import numpy as np

# %%
x = np.linspace(0, 1, num = 100)
y = np.exp(x)
def exp(x):
    return exp(x)
    y = exp({x})

# %%
f = plt.figure(figsize=(6,6))

plt.plot(x,y)

ax.set_xlim([0,1])
ax.set_ylim([0,1])

plt.xlabel('Time[milliseconds]')
plt.ylabel('Awesomeness')

plt.savefig('prompt7plot.pdf',bbox_inches='tight',facecolor='white')
